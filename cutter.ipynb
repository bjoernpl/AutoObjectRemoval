# %% [markdown]
# # AutoObjectRemoval
# ## AI based object removal system for videos

# %% [markdown]
# ### 1. Choose a video to be processed
# This video will be rescaled to 960 x 512 pixels and cut up into frames.
# Note that this will consume a lot of storage space for long videos.

# %%
from pathlib import Path
import os


video_path = Path("./res/videos/skate.mp4")
out_dir_name = f"./outputs/{video_path.stem}_%s"
i = 0
while os.path.exists(out_dir_name % i):
    i += 1
output_dir = Path(out_dir_name % i).resolve()
# !mkdir -p {output_dir}
intermediate = Path(output_dir / "intermediates")

# %% [markdown]
# ### 1.1 Video Preprocessing

# %%
amount_of_frames = 150
# !mkdir -p {intermediate}/frames
# !mkdir -p {intermediate}/masks
# !ffmpeg -i {video_path} -frames:v {amount_of_frames} -vf scale="960:512" {intermediate}/frames/%03d.png

# %% [markdown]
# ### 2. Generating masks object removal
# For this step the Detectron2 instance segmentation model trained on MS-COCO dataset is used.
# Any of the 80 objects in that dataset can be used for extraction.
# You can find a list of these class names [here](https://github.com/amikelive/coco-labels/blob/master/coco-labels-2014_2017.txt).

# %% [markdown]
# #### 2.1 Load Detectron2 model

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
from tqdm import tqdm
from PIL import Image

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
class_names = predictor.metadata.thing_classes

# %% [markdown]
# #### 2.2 Load frames and apply model

# %%
# Load frames
frames = intermediate / "frames/"
imgs = [cv2.imread(str(path)) for path in frames.glob("*.png")]

# %%
# Inference on each of the frames
outputs = [predictor(img) for img in imgs]

# %% [markdown]
# #### 2.3 Extract masks for chosen object to be removed

# %%
# Function to turn mask of shape (width, height) to shape (width, height, 3)
def to_rgb(im):
    w, h = im.shape
    ret = np.empty((w, h, 3))
    ret[:, :, 2] =  ret[:, :, 1] =  ret[:, :, 0] =  im
    return ret

# %% [markdown]
# Here `expand_mask(mask)` is a utility function that is used to expand the generated mask by some padding to make
# sure that the object intended for removal is fully masked.

# %%
def expand_mask(mask, padding=15):
    mask_cpy = mask.copy()
    for x in range(mask.shape[0]):
        for y in range(mask.shape[1]):
            if mask[x,y] == 1:
                if padding < x < mask.shape[0]-padding and padding < y < mask.shape[1]-padding:
                    if 0 in [mask[x+xoff, y+yoff] for xoff in range(-1,2) for yoff in range(-1, 2)]:
                        for px in range(-padding, padding):
                            for py in range(-padding, padding):
                                mask_cpy[x+px,y+py] = 1
    return mask_cpy

# %% [markdown]
# #### 2.4 Combining and saving masks from inference results
# Choose the labels of each object class which shall be removed and this loop
# will combine the masks of all detected objects in `labels_of_objects_to_remove`
# for each frame.

# %%
labels_of_objects_to_remove = ["person", "skateboard"]
max_objects_to_detect = 2
indices =  [class_names.index(label) for label in labels_of_objects_to_remove]
for i, (img, pred) in tqdm(enumerate(zip(imgs, outputs))):
    shape = img.shape
    created_mask = False
    mask = np.zeros(shape)
    if pred is not None:
        instance = pred["instances"]
        for x in range(len(instance.pred_classes))[:max_objects_to_detect]:
            if instance.pred_classes[x] in indices:
                mask_arr = instance.pred_masks[x].cpu().numpy()
                mask += to_rgb(expand_mask(mask_arr))
    mask_img = Image.fromarray((mask * 255).astype(np.uint8))
    mask_img.save(intermediate / "masks" / f"{i}.png")
                
print('Finished creating masks.')

# %% [markdown]
# ### 3. Object removal with FGVC
# Make sure that you have set up the environments `FGVC` and `raft` according to setup.readme.
# For 3.1 ensure that `raft` is activated. When prompted with `Please switch to torch 0.4.0`, deactivate `FGVC` and activate `raft`.

# %%
frames = frames.resolve()
masks = (intermediate/"masks").resolve()

# !bash -i run_video_completion.sh "raft" {frames} {masks} {output_dir}

# %%
# !bash -i run_video_completion.sh "FGVC" {frames} {masks} {output_dir}

# %%
from ipywidgets import Video
Video.fromfile(f"{output_dir}/frame_seamless_comp_0/video_extrapolation.mp4")

# %% [markdown]
# from ipywidgets import Video
# Video.fromfile(f"{output_dir}/frame_seamless_comp_0/video_extrapolation.mp4")

# %%
from pathlib import Path
import os

video_path = Path("./res/videos/skate.mp4")
out_dir_name = f"./outputs/{video_path.stem}_%s"
i = 0
while os.path.exists(out_dir_name % i):
    i += 1
output_dir = Path(out_dir_name % i).resolve()
# !mkdir -p {output_dir}
intermediate = Path(output_dir / "intermediates")

# %% [markdown]
# ### 1.1 Video Preprocessing

# %%
amount_of_frames = 150
# !mkdir -p {intermediate}/frames
# !mkdir -p {intermediate}/masks
# Here 25fps (youtube) is assumed. For best results adjust to correct fps
# !ffmpeg -i {video_path} -frames:v {amount_of_frames} -vf scale="960:512" {intermediate}/frames/%03d.png
# Out:
# ffmpeg version 4.0 Copyright (c) 2000-2018 the FFmpeg developers
#   built with gcc 7.2.0 (crosstool-NG fa8859cb)
#   configuration: --prefix=/home/bjorn/anaconda3/envs/raft --cc=/opt/conda/conda-bld/ffmpeg_1531088893642/_build_env/bin/x86_64-conda_cos6-linux-gnu-cc --disable-doc --enable-shared --enable-static --enable-zlib --enable-pic --enable-gpl --enable-version3 --disable-nonfree --enable-hardcoded-tables --enable-avresample --enable-libfreetype --disable-openssl --disable-gnutls --enable-libvpx --enable-pthreads --enable-libopus --enable-postproc --disable-libx264
#   libavutil      56. 14.100 / 56. 14.100
#   libavcodec     58. 18.100 / 58. 18.100
#   libavformat    58. 12.100 / 58. 12.100
#   libavdevice    58.  3.100 / 58.  3.100
#   libavfilter     7. 16.100 /  7. 16.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  1.100 /  5.  1.100
#   libswresample   3.  1.100 /  3.  1.100
#   libpostproc    55.  1.100 / 55.  1.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'res/videos/skate.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:01:00.03, start: 0.000000, bitrate: 3601 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 3463 kb/s, 29.97 fps, 29.97 tbr, 16k tbn, 59.94 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(por): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, stereo, fltp, 128 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> png (native))
# Press [q] to stop, [?] for help
# Output #0, image2, to '/mnt/c/Users/Björn/Documents/MiscCode/cutter/outputs/skate_0/intermediates/frames/%03d.png':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#     Stream #0:0(und): Video: png, rgb24, 960x512 [SAR 128:135 DAR 16:9], q=2-31, 200 kb/s, 29.97 fps, 29.97 tbn, 29.97 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.18.100 png
# frame=  150 fps= 83 q=-0.0 Lsize=N/A time=00:00:05.00 bitrate=N/A speed=2.76x
# video:118998kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: unknown

# %% [markdown]
# ### 2. Extracting bounding boxes for object which shall be removed
# For this step the YOLOv5 object detection model trained on MS-COCO dataset is used. Any of the 80 objects in that dataset can be used for extraction.
# You can find a list of these class names [here](https://github.com/amikelive/coco-labels/blob/master/coco-labels-2014_2017.txt).

# %% [markdown]
# #### 2.1 Load YOLO model

# %%
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
cfg = get_cfg()
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)

# %% [markdown]
# #### 2.2 Load frames and apply model

# %%
# Load frames
frames = intermediate / "frames/"
imgs = [cv2.imread(str(path)) for path in frames.glob("*.png")]

# %%
# Inference on each of the frames
outputs = [predictor(img) for img in imgs]
# Out:
# /home/bjorn/anaconda3/envs/raft/lib/python3.7/site-packages/detectron2/layers/wrappers.py:125: UserWarning: This overload of nonzero is deprecated:
# 	nonzero()
# Consider using one of the following signatures instead:
# 	nonzero(*, bool as_tuple) (Triggered internally at  /opt/conda/conda-bld/pytorch_1595629427478/work/torch/csrc/utils/python_arg_parser.cpp:766.)
#   return x.nonzero().unbind(1)

# %%
#print(outputs[0]["instances"].pred_masks.shape)
class_names = predictor.metadata.thing_classes

# %% [markdown]
# #### 2.3 Extract masks for chosen object to be removed

# %%
from tqdm import tqdm
from PIL import Image

# Function to turn mask of shape (width, height) to shape (width, height, 3)
def to_rgb(im):
    w, h = im.shape
    ret = np.empty((w, h, 3))
    ret[:, :, 2] =  ret[:, :, 1] =  ret[:, :, 0] =  im
    return ret

# %%
def expand_mask(mask):
    mask_cpy = mask.copy()
    padding = 25
    for x in range(mask.shape[0]):
        for y in range(mask.shape[1]):
            if mask[x,y] == 1:
                if x > padding and y > padding and x < mask.shape[0]-padding and y < mask.shape[1]-padding:
                    if 0 in [mask[x+xoff, y+yoff] for xoff in range(-1,2) for yoff in range(-1, 2)]:
                        for px in range(-padding, padding):
                            for py in range(-padding, padding):
                                mask_cpy[x+px,y+py] = 1
    return mask_cpy

# %%
labels_of_objects_to_remove = ["person", "skateboard"]
max_objects_to_detect = 2
indices =  [class_names.index(label) for label in labels_of_objects_to_remove]
for i, (img, pred) in tqdm(enumerate(zip(imgs, outputs))):
    shape = img.shape
    created_mask = False
    mask = np.zeros(shape)
    if pred is not None:
        instance = pred["instances"]
        for x in range(len(instance.pred_classes))[:max_objects_to_detect]:
            if instance.pred_classes[x] in indices:
                mask_arr = instance.pred_masks[x].cpu().numpy()
                mask += to_rgb(expand_mask(mask_arr))
    mask_img = Image.fromarray((mask * 255).astype(np.uint8))
    mask_img.save(intermediate / "masks" / f"{i}.png")
                
print('Finished creating masks.')
# Out:
# 150it [03:04,  1.23s/it]
# Finished creating masks.

# %% [markdown]
# ### 3. Object removal with FGVC
# Make sure that you have set up the environments `FGVC` and `raft` according to setup.readme.
# For 3.1 ensure that `raft` is activated. When prompted with `Please switch to torch 0.4.0`, deactivate `FGVC` and activate `raft`.

# %%
frames = frames.resolve()
masks = (intermediate/"masks").resolve()

# !bash -i run_video_completion.sh "raft" {frames} {masks} {output_dir}
# Out:
# Pytorch 1.6.0 for flow prediction
# Completing backward flow 148 <---> 149
# Finish Calculating flow.
# Completing forward flow  0 <--->  1
# Completing forward flow  1 <--->  2
# Completing forward flow  2 <--->  3
# Completing forward flow  3 <--->  4
# Completing forward flow  4 <--->  5
# Completing forward flow  5 <--->  6
# Completing forward flow  6 <--->  7
# Completing forward flow  7 <--->  8
# Completing forward flow  8 <--->  9
# Completing forward flow  9 <---> 10
# Completing forward flow 10 <---> 11
# Completing forward flow 11 <---> 12
# Completing forward flow 12 <---> 13
# Completing forward flow 13 <---> 14
# Completing forward flow 14 <---> 15
# Completing forward flow 15 <---> 16
# Completing forward flow 16 <---> 17
# Completing forward flow 17 <---> 18
# Completing forward flow 18 <---> 19
# Completing forward flow 19 <---> 20
# Completing forward flow 20 <---> 21
# Completing forward flow 21 <---> 22
# Completing forward flow 22 <---> 23
# Completing forward flow 23 <---> 24
# Completing forward flow 24 <---> 25
# Completing forward flow 25 <---> 26
# Completing forward flow 26 <---> 27
# Completing forward flow 27 <---> 28
# Completing forward flow 28 <---> 29
# Completing forward flow 29 <---> 30
# Completing forward flow 30 <---> 31
# Completing forward flow 31 <---> 32
# Completing forward flow 32 <---> 33
# Completing forward flow 33 <---> 34
# Completing forward flow 34 <---> 35
# Completing forward flow 35 <---> 36
# Completing forward flow 36 <---> 37
# Completing forward flow 37 <---> 38
# Completing forward flow 38 <---> 39
# Completing forward flow 39 <---> 40
# Completing forward flow 40 <---> 41
# Completing forward flow 41 <---> 42
# Completing forward flow 42 <---> 43
# Completing forward flow 43 <---> 44
# Completing forward flow 44 <---> 45
# Completing forward flow 45 <---> 46
# Completing forward flow 46 <---> 47
# Completing forward flow 47 <---> 48
# Completing forward flow 48 <---> 49
# Completing forward flow 49 <---> 50
# Completing forward flow 50 <---> 51
# Completing forward flow 51 <---> 52
# Completing forward flow 52 <---> 53
# Completing forward flow 53 <---> 54
# Completing forward flow 54 <---> 55
# Completing forward flow 55 <---> 56
# Completing forward flow 56 <---> 57
# Completing forward flow 57 <---> 58
# Completing forward flow 58 <---> 59
# Completing forward flow 59 <---> 60
# Completing forward flow 60 <---> 61
# Completing forward flow 61 <---> 62
# Completing forward flow 62 <---> 63
# Completing forward flow 63 <---> 64
# Completing forward flow 64 <---> 65
# Completing forward flow 65 <---> 66
# Completing forward flow 66 <---> 67
# Completing forward flow 67 <---> 68
# Completing forward flow 68 <---> 69
# Completing forward flow 69 <---> 70
# Completing forward flow 70 <---> 71
# Completing forward flow 71 <---> 72
# Completing forward flow 72 <---> 73
# Completing forward flow 73 <---> 74
# Completing forward flow 74 <---> 75
# Completing forward flow 75 <---> 76
# Completing forward flow 76 <---> 77
# Completing forward flow 77 <---> 78
# Completing forward flow 78 <---> 79
# Completing forward flow 79 <---> 80
# Completing forward flow 80 <---> 81
# Completing forward flow 81 <---> 82
# Completing forward flow 82 <---> 83
# Completing forward flow 83 <---> 84
# Completing forward flow 84 <---> 85
# Completing forward flow 85 <---> 86
# Completing forward flow 86 <---> 87
# Completing forward flow 87 <---> 88
# Completing forward flow 88 <---> 89
# Completing forward flow 89 <---> 90
# Completing forward flow 90 <---> 91
# Completing forward flow 91 <---> 92
# Completing forward flow 92 <---> 93
# Completing forward flow 93 <---> 94
# Completing forward flow 94 <---> 95
# Completing forward flow 95 <---> 96
# Completing forward flow 96 <---> 97
# Completing forward flow 97 <---> 98
# Completing forward flow 98 <---> 99
# Completing forward flow 99 <---> 100
# Completing forward flow 100 <---> 101
# Completing forward flow 101 <---> 102
# Completing forward flow 102 <---> 103
# Completing forward flow 103 <---> 104
# Completing forward flow 104 <---> 105
# Completing forward flow 105 <---> 106
# Completing forward flow 106 <---> 107
# Completing forward flow 107 <---> 108
# Completing forward flow 108 <---> 109
# Completing forward flow 109 <---> 110
# Completing forward flow 110 <---> 111
# Completing forward flow 111 <---> 112
# Completing forward flow 112 <---> 113
# Completing forward flow 113 <---> 114
# Completing forward flow 114 <---> 115
# Completing forward flow 115 <---> 116
# Completing forward flow 116 <---> 117
# Completing forward flow 117 <---> 118
# Completing forward flow 118 <---> 119
# Completing forward flow 119 <---> 120
# Completing forward flow 120 <---> 121
# Completing forward flow 121 <---> 122
# Completing forward flow 122 <---> 123
# Completing forward flow 123 <---> 124
# Completing forward flow 124 <---> 125
# Completing forward flow 125 <---> 126
# Completing forward flow 126 <---> 127
# Completing forward flow 127 <---> 128
# Completing forward flow 128 <---> 129
# Completing forward flow 129 <---> 130
# Completing forward flow 130 <---> 131
# Completing forward flow 131 <---> 132
# Completing forward flow 132 <---> 133
# Completing forward flow 133 <---> 134
# Completing forward flow 134 <---> 135
# Completing forward flow 135 <---> 136
# Completing forward flow 136 <---> 137
# Completing forward flow 137 <---> 138
# Completing forward flow 138 <---> 139
# Completing forward flow 139 <---> 140
# Completing forward flow 140 <---> 141
# Completing forward flow 141 <---> 142
# Completing forward flow 142 <---> 143
# Completing forward flow 143 <---> 144
# Completing forward flow 144 <---> 145
# Completing forward flow 145 <---> 146
# Completing forward flow 146 <---> 147
# Completing forward flow 147 <---> 148
# Completing forward flow 148 <---> 149
# Completing backward flow  0 <--->  1
# Completing backward flow  1 <--->  2
# Completing backward flow  2 <--->  3
# Completing backward flow  3 <--->  4
# Completing backward flow  4 <--->  5
# Completing backward flow  5 <--->  6
# Completing backward flow  6 <--->  7
# Completing backward flow  7 <--->  8
# Completing backward flow  8 <--->  9
# Completing backward flow  9 <---> 10
# Completing backward flow 10 <---> 11
# Completing backward flow 11 <---> 12
# Completing backward flow 12 <---> 13
# Completing backward flow 13 <---> 14
# Completing backward flow 14 <---> 15
# Completing backward flow 15 <---> 16
# Completing backward flow 16 <---> 17
# Completing backward flow 17 <---> 18
# Completing backward flow 18 <---> 19
# Completing backward flow 19 <---> 20
# Completing backward flow 20 <---> 21
# Completing backward flow 21 <---> 22
# Completing backward flow 22 <---> 23
# Completing backward flow 23 <---> 24
# Completing backward flow 24 <---> 25
# Completing backward flow 25 <---> 26
# Completing backward flow 26 <---> 27
# Completing backward flow 27 <---> 28
# Completing backward flow 28 <---> 29
# Completing backward flow 29 <---> 30
# Completing backward flow 30 <---> 31
# Completing backward flow 31 <---> 32
# Completing backward flow 32 <---> 33
# Completing backward flow 33 <---> 34
# Completing backward flow 34 <---> 35
# Completing backward flow 35 <---> 36
# Completing backward flow 36 <---> 37
# Completing backward flow 37 <---> 38
# Completing backward flow 38 <---> 39
# Completing backward flow 39 <---> 40
# Completing backward flow 40 <---> 41
# Completing backward flow 41 <---> 42
# Completing backward flow 42 <---> 43
# Completing backward flow 43 <---> 44
# Completing backward flow 44 <---> 45
# Completing backward flow 45 <---> 46
# Completing backward flow 46 <---> 47
# Completing backward flow 47 <---> 48
# Completing backward flow 48 <---> 49
# Completing backward flow 49 <---> 50
# Completing backward flow 50 <---> 51
# Completing backward flow 51 <---> 52
# Completing backward flow 52 <---> 53
# Completing backward flow 53 <---> 54
# Completing backward flow 54 <---> 55
# Completing backward flow 55 <---> 56
# Completing backward flow 56 <---> 57
# Completing backward flow 57 <---> 58
# Completing backward flow 58 <---> 59
# Completing backward flow 59 <---> 60
# Completing backward flow 60 <---> 61
# Completing backward flow 61 <---> 62
# Completing backward flow 62 <---> 63
# Completing backward flow 63 <---> 64
# Completing backward flow 64 <---> 65
# Completing backward flow 65 <---> 66
# Completing backward flow 66 <---> 67
# Completing backward flow 67 <---> 68
# Completing backward flow 68 <---> 69
# Completing backward flow 69 <---> 70
# Completing backward flow 70 <---> 71
# Completing backward flow 71 <---> 72
# Completing backward flow 72 <---> 73
# Completing backward flow 73 <---> 74
# Completing backward flow 74 <---> 75
# Completing backward flow 75 <---> 76
# Completing backward flow 76 <---> 77
# Completing backward flow 77 <---> 78
# Completing backward flow 78 <---> 79
# Completing backward flow 79 <---> 80
# Completing backward flow 80 <---> 81
# Completing backward flow 81 <---> 82
# Completing backward flow 82 <---> 83
# Completing backward flow 83 <---> 84
# Completing backward flow 84 <---> 85
# Completing backward flow 85 <---> 86
# Completing backward flow 86 <---> 87
# Completing backward flow 87 <---> 88
# Completing backward flow 88 <---> 89
# Completing backward flow 89 <---> 90
# Completing backward flow 90 <---> 91
# Completing backward flow 91 <---> 92
# Completing backward flow 92 <---> 93
# Completing backward flow 93 <---> 94
# Completing backward flow 94 <---> 95
# Completing backward flow 95 <---> 96
# Completing backward flow 96 <---> 97
# Completing backward flow 97 <---> 98
# Completing backward flow 98 <---> 99
# Completing backward flow 99 <---> 100
# Completing backward flow 100 <---> 101
# Completing backward flow 101 <---> 102
# Completing backward flow 102 <---> 103
# Completing backward flow 103 <---> 104
# Completing backward flow 104 <---> 105
# Completing backward flow 105 <---> 106
# Completing backward flow 106 <---> 107
# Completing backward flow 107 <---> 108
# Completing backward flow 108 <---> 109
# Completing backward flow 109 <---> 110
# Completing backward flow 110 <---> 111
# Completing backward flow 111 <---> 112
# Completing backward flow 112 <---> 113
# Completing backward flow 113 <---> 114
# Completing backward flow 114 <---> 115
# Completing backward flow 115 <---> 116
# Completing backward flow 116 <---> 117
# Completing backward flow 117 <---> 118
# Completing backward flow 118 <---> 119
# Completing backward flow 119 <---> 120
# Completing backward flow 120 <---> 121
# Completing backward flow 121 <---> 122
# Completing backward flow 122 <---> 123
# Completing backward flow 123 <---> 124
# Completing backward flow 124 <---> 125
# Completing backward flow 125 <---> 126
# Completing backward flow 126 <---> 127
# Completing backward flow 127 <---> 128
# Completing backward flow 128 <---> 129
# Completing backward flow 129 <---> 130
# Completing backward flow 130 <---> 131
# Completing backward flow 131 <---> 132
# Completing backward flow 132 <---> 133
# Completing backward flow 133 <---> 134
# Completing backward flow 134 <---> 135
# Completing backward flow 135 <---> 136
# Completing backward flow 136 <---> 137
# Completing backward flow 137 <---> 138
# Completing backward flow 138 <---> 139
# Completing backward flow 139 <---> 140
# Completing backward flow 140 <---> 141
# Completing backward flow 141 <---> 142
# Completing backward flow 142 <---> 143
# Completing backward flow 143 <---> 144
# Completing backward flow 144 <---> 145
# Completing backward flow 145 <---> 146
# Completing backward flow 146 <---> 147
# Completing backward flow 147 <---> 148
# Completing backward flow 148 <---> 149
# Please switch to Pytorch 0.4.0
# done

# %%
# !bash -i run_video_completion.sh "FGVC" {frames} {masks} {output_dir}
# Out:
# Pytorch 1.6.0 for flow prediction
# Loading /mnt/c/Users/Björn/Documents/MiscCode/cutter/outputs/skate_0/flow/backward_flo/00148.flo
# Finish Calculating flow.
# Load Deepfill Model from ../weight/imagenet_deepfill.pth
# Forward Pass......
# (512, 960, 2, 149)
# Frame   1:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame   2:    68148 +        0 =    68148
# (512, 960, 2, 149)
# Frame   3:    60979 +        0 =    60979
# (512, 960, 2, 149)
# Frame   4:    70430 +      216 =    70646
# (512, 960, 2, 149)
# Frame   5:    70716 +      398 =    71114
# (512, 960, 2, 149)
# Frame   6:    64621 +      555 =    65176
# (512, 960, 2, 149)
# Frame   7:    67260 +      533 =    67793
# (512, 960, 2, 149)
# Frame   8:    71564 +      135 =    71699
# (512, 960, 2, 149)
# Frame   9:    73824 +      207 =    74031
# (512, 960, 2, 149)
# Frame  10:    78793 +      331 =    79124
# (512, 960, 2, 149)
# Frame  11:    78717 +      382 =    79099
# (512, 960, 2, 149)
# Frame  12:    77876 +      430 =    78306
# (512, 960, 2, 149)
# Frame  13:    59659 +      645 =    60304
# (512, 960, 2, 149)
# Frame  14:    77426 +      448 =    77874
# (512, 960, 2, 149)
# Frame  15:    77560 +      311 =    77871
# (512, 960, 2, 149)
# Frame  16:    76681 +      815 =    77496
# (512, 960, 2, 149)
# Frame  17:    75351 +     1565 =    76916
# (512, 960, 2, 149)
# Frame  18:    73190 +     2776 =    75966
# (512, 960, 2, 149)
# Frame  19:    72416 +     3940 =    76356
# (512, 960, 2, 149)
# Frame  20:    66067 +     4872 =    70939
# (512, 960, 2, 149)
# Frame  21:    65188 +     5406 =    70594
# (512, 960, 2, 149)
# Frame  22:    68647 +     5767 =    74414
# (512, 960, 2, 149)
# Frame  23:    68848 +     6225 =    75073
# (512, 960, 2, 149)
# Frame  24:    59147 +     1869 =    61016
# (512, 960, 2, 149)
# Frame  25:    74641 +     1660 =    76301
# (512, 960, 2, 149)
# Frame  26:    80873 +     2049 =    82922
# (512, 960, 2, 149)
# Frame  27:    76579 +     2388 =    78967
# (512, 960, 2, 149)
# Frame  28:    75191 +     2537 =    77728
# (512, 960, 2, 149)
# Frame  29:    74049 +     2415 =    76464
# (512, 960, 2, 149)
# Frame  30:    76588 +     2186 =    78774
# (512, 960, 2, 149)
# Frame  31:    75701 +     1959 =    77660
# (512, 960, 2, 149)
# Frame  32:    74186 +     1613 =    75799
# (512, 960, 2, 149)
# Frame  33:    73416 +     1130 =    74546
# (512, 960, 2, 149)
# Frame  34:    72615 +      602 =    73217
# (512, 960, 2, 149)
# Frame  35:    41930 +      442 =    42372
# (512, 960, 2, 149)
# Frame  36:    70655 +       21 =    70676
# (512, 960, 2, 149)
# Frame  37:    69446 +       37 =    69483
# (512, 960, 2, 149)
# Frame  38:    66352 +        7 =    66359
# (512, 960, 2, 149)
# Frame  39:    62514 +        0 =    62514
# (512, 960, 2, 149)
# Frame  40:    58824 +        0 =    58824
# (512, 960, 2, 149)
# Frame  41:    54482 +        0 =    54482
# (512, 960, 2, 149)
# Frame  42:    51852 +        0 =    51852
# (512, 960, 2, 149)
# Frame  43:    47423 +        0 =    47423
# (512, 960, 2, 149)
# Frame  44:    45342 +        0 =    45342
# (512, 960, 2, 149)
# Frame  45:    43405 +        0 =    43405
# (512, 960, 2, 149)
# Frame  46:    62276 +      788 =    63064
# (512, 960, 2, 149)
# Frame  47:    42539 +        0 =    42539
# (512, 960, 2, 149)
# Frame  48:    41474 +        0 =    41474
# (512, 960, 2, 149)
# Frame  49:    40683 +        0 =    40683
# (512, 960, 2, 149)
# Frame  50:    41077 +        0 =    41077
# (512, 960, 2, 149)
# Frame  51:    40576 +     2094 =    42670
# (512, 960, 2, 149)
# Frame  52:    44632 +     5548 =    50180
# (512, 960, 2, 149)
# Frame  53:    43490 +     8586 =    52076
# (512, 960, 2, 149)
# Frame  54:    41787 +    10333 =    52120
# (512, 960, 2, 149)
# Frame  55:    41292 +     9678 =    50970
# (512, 960, 2, 149)
# Frame  56:    41025 +     8382 =    49407
# (512, 960, 2, 149)
# Frame  57:    66516 +        0 =    66516
# (512, 960, 2, 149)
# Frame  58:    66117 +      109 =    66226
# (512, 960, 2, 149)
# Frame  59:    54659 +      141 =    54800
# (512, 960, 2, 149)
# Frame  60:    61041 +       51 =    61092
# (512, 960, 2, 149)
# Frame  61:    59746 +        0 =    59746
# (512, 960, 2, 149)
# Frame  62:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  63:    60433 +        0 =    60433
# (512, 960, 2, 149)
# Frame  64:    61516 +        0 =    61516
# (512, 960, 2, 149)
# Frame  65:    64707 +        0 =    64707
# (512, 960, 2, 149)
# Frame  66:    68856 +        0 =    68856
# (512, 960, 2, 149)
# Frame  67:    68084 +        0 =    68084
# (512, 960, 2, 149)
# Frame  68:    70476 +        0 =    70476
# (512, 960, 2, 149)
# Frame  69:    68015 +        0 =    68015
# (512, 960, 2, 149)
# Frame  70:    68528 +        0 =    68528
# (512, 960, 2, 149)
# Frame  71:    68966 +        0 =    68966
# (512, 960, 2, 149)
# Frame  72:    69505 +        0 =    69505
# (512, 960, 2, 149)
# Frame  73:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  74:    67555 +        0 =    67555
# (512, 960, 2, 149)
# Frame  75:    66121 +        0 =    66121
# (512, 960, 2, 149)
# Frame  76:    64016 +        0 =    64016
# (512, 960, 2, 149)
# Frame  77:    63298 +        0 =    63298
# (512, 960, 2, 149)
# Frame  78:    62318 +        0 =    62318
# (512, 960, 2, 149)
# Frame  79:    58689 +        0 =    58689
# (512, 960, 2, 149)
# Frame  80:    58962 +        0 =    58962
# (512, 960, 2, 149)
# Frame  81:    57849 +        0 =    57849
# (512, 960, 2, 149)
# Frame  82:    58028 +        0 =    58028
# (512, 960, 2, 149)
# Frame  83:    52760 +        0 =    52760
# (512, 960, 2, 149)
# Frame  84:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  85:    54126 +        0 =    54126
# (512, 960, 2, 149)
# Frame  86:    51661 +        0 =    51661
# (512, 960, 2, 149)
# Frame  87:    50321 +        0 =    50321
# (512, 960, 2, 149)
# Frame  88:    48701 +        0 =    48701
# (512, 960, 2, 149)
# Frame  89:    45879 +        0 =    45879
# (512, 960, 2, 149)
# Frame  90:    50582 +        0 =    50582
# (512, 960, 2, 149)
# Frame  91:    47732 +        0 =    47732
# (512, 960, 2, 149)
# Frame  92:    43498 +        0 =    43498
# (512, 960, 2, 149)
# Frame  93:    41515 +        0 =    41515
# (512, 960, 2, 149)
# Frame  94:    38864 +        0 =    38864
# (512, 960, 2, 149)
# Frame  95:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  96:    38638 +        0 =    38638
# (512, 960, 2, 149)
# Frame  97:    40748 +        0 =    40748
# (512, 960, 2, 149)
# Frame  98:    39103 +        0 =    39103
# (512, 960, 2, 149)
# Frame  99:    40718 +        0 =    40718
# (512, 960, 2, 149)
# Frame 100:    40242 +        0 =    40242
# (512, 960, 2, 149)
# Frame 101:    41292 +       38 =    41330
# (512, 960, 2, 149)
# Frame 102:    41237 +       79 =    41316
# (512, 960, 2, 149)
# Frame 103:    40247 +      131 =    40378
# (512, 960, 2, 149)
# Frame 104:    40061 +      206 =    40267
# (512, 960, 2, 149)
# Frame 105:    38028 +      252 =    38280
# (512, 960, 2, 149)
# Frame 106:    67346 +        0 =    67346
# (512, 960, 2, 149)
# Frame 107:    37533 +      208 =    37741
# (512, 960, 2, 149)
# Frame 108:    38952 +      283 =    39235
# (512, 960, 2, 149)
# Frame 109:    38053 +      284 =    38337
# (512, 960, 2, 149)
# Frame 110:    37877 +      279 =    38156
# (512, 960, 2, 149)
# Frame 111:    37857 +      333 =    38190
# (512, 960, 2, 149)
# Frame 112:    37206 +      362 =    37568
# (512, 960, 2, 149)
# Frame 113:    36618 +      269 =    36887
# (512, 960, 2, 149)
# Frame 114:    36394 +      185 =    36579
# (512, 960, 2, 149)
# Frame 115:    34937 +      118 =    35055
# (512, 960, 2, 149)
# Frame 116:    33661 +      230 =    33891
# (512, 960, 2, 149)
# Frame 117:    11570 +        0 =    11570
# (512, 960, 2, 149)
# Frame 118:    32850 +      121 =    32971
# (512, 960, 2, 149)
# Frame 119:    32129 +      201 =    32330
# (512, 960, 2, 149)
# Frame 120:    31972 +      283 =    32255
# (512, 960, 2, 149)
# Frame 121:    32512 +      240 =    32752
# (512, 960, 2, 149)
# Frame 122:    32455 +      281 =    32736
# (512, 960, 2, 149)
# Frame 123:    32028 +      275 =    32303
# (512, 960, 2, 149)
# Frame 124:    32656 +      331 =    32987
# (512, 960, 2, 149)
# Frame 125:    33040 +      303 =    33343
# (512, 960, 2, 149)
# Frame 126:    36828 +      376 =    37204
# (512, 960, 2, 149)
# Frame 127:    40981 +      621 =    41602
# (512, 960, 2, 149)
# Frame 128:    80788 +      934 =    81722
# (512, 960, 2, 149)
# Frame 129:    41349 +     1009 =    42358
# (512, 960, 2, 149)
# Frame 130:    43320 +     1221 =    44541
# (512, 960, 2, 149)
# Frame 131:    43936 +     1608 =    45544
# (512, 960, 2, 149)
# Frame 132:    42412 +     1957 =    44369
# (512, 960, 2, 149)
# Frame 133:    44682 +     2301 =    46983
# (512, 960, 2, 149)
# Frame 134:    45659 +     2705 =    48364
# (512, 960, 2, 149)
# Frame 135:    47253 +     2825 =    50078
# (512, 960, 2, 149)
# Frame 136:    47333 +     3007 =    50340
# (512, 960, 2, 149)
# Frame 137:    46620 +     2998 =    49618
# (512, 960, 2, 149)
# Frame 138:    49118 +     3011 =    52129
# (512, 960, 2, 149)
# Frame 139:    69405 +     2888 =    72293
# (512, 960, 2, 149)
# Frame 140:    51621 +     2402 =    54023
# (512, 960, 2, 149)
# Frame 141:    52134 +     2634 =    54768
# (512, 960, 2, 149)
# Frame 142:    53056 +     3070 =    56126
# (512, 960, 2, 149)
# Frame 143:    54050 +     3387 =    57437
# (512, 960, 2, 149)
# Frame 144:    54301 +     3852 =    58153
# (512, 960, 2, 149)
# Frame 145:    51968 +     4485 =    56453
# (512, 960, 2, 149)
# Frame 146:    56093 +     4943 =    61036
# (512, 960, 2, 149)
# Frame 147:    57627 +     5245 =    62872
# (512, 960, 2, 149)
# Frame 148:    53979 +     4790 =    58769
# (512, 960, 2, 149)
# Frame 149:    55366 +     4129 =    59495
# Backward Pass......
# Frame 148:     3696 +    55073 =    58769
# Frame 147:    11858 +    51014 =    62872
# Frame 146:    12698 +    48338 =    61036
# Frame 145:    11118 +    45335 =    56453
# Frame 144:    14787 +    43366 =    58153
# Frame 143:    15705 +    41732 =    57437
# Frame 142:    16545 +    39581 =    56126
# Frame 141:    17250 +    37518 =    54768
# Frame 140:    18281 +    35742 =    54023
# Frame 139:    55196 +    17097 =    72293
# Frame 138:    35140 +    16989 =    52129
# Frame 137:    33972 +    15646 =    49618
# Frame 136:    35041 +    15299 =    50340
# Frame 135:    35863 +    14215 =    50078
# Frame 134:    36135 +    12229 =    48364
# Frame 133:    35747 +    11236 =    46983
# Frame 132:    36451 +     7918 =    44369
# Frame 131:    40593 +     4951 =    45544
# Frame 130:    41983 +     2558 =    44541
# Frame 129:    41442 +      916 =    42358
# Frame 128:    81006 +      716 =    81722
# Frame 127:    41348 +      254 =    41602
# Frame 126:    37204 +        0 =    37204
# Frame 125:    33343 +        0 =    33343
# Frame 124:    32987 +        0 =    32987
# Frame 123:    32303 +        0 =    32303
# Frame 122:    32736 +        0 =    32736
# Frame 121:    32738 +       14 =    32752
# Frame 120:    32183 +       72 =    32255
# Frame 119:    32290 +       40 =    32330
# Frame 118:    32961 +       10 =    32971
# Frame 117:    11570 +        0 =    11570
# Frame 116:    33891 +        0 =    33891
# Frame 115:    35055 +        0 =    35055
# Frame 114:    36562 +       17 =    36579
# Frame 113:    36873 +       14 =    36887
# Frame 112:    37561 +        7 =    37568
# Frame 111:    38190 +        0 =    38190
# Frame 110:    38156 +        0 =    38156
# Frame 109:    38337 +        0 =    38337
# Frame 108:    39235 +        0 =    39235
# Frame 107:    37741 +        0 =    37741
# Frame 106:    67346 +        0 =    67346
# Frame 105:    38278 +        2 =    38280
# Frame 104:    40264 +        3 =    40267
# Frame 103:    40361 +       17 =    40378
# Frame 102:    41292 +       24 =    41316
# Frame 101:    41287 +       43 =    41330
# Frame 100:    40133 +      109 =    40242
# Frame  99:    40557 +      161 =    40718
# Frame  98:    38889 +      214 =    39103
# Frame  97:    40453 +      295 =    40748
# Frame  96:    38231 +      407 =    38638
# Frame  95:        0 +        0 =        0
# Frame  94:    38638 +      226 =    38864
# Frame  93:    41193 +      322 =    41515
# Frame  92:    43077 +      421 =    43498
# Frame  91:    47184 +      548 =    47732
# Frame  90:    49758 +      824 =    50582
# Frame  89:    44752 +     1127 =    45879
# Frame  88:    47087 +     1614 =    48701
# Frame  87:    48446 +     1875 =    50321
# Frame  86:    49471 +     2190 =    51661
# Frame  85:    51483 +     2643 =    54126
# Frame  84:        0 +        0 =        0
# Frame  83:    52031 +      729 =    52760
# Frame  82:    56473 +     1555 =    58028
# Frame  81:    55363 +     2486 =    57849
# Frame  80:    56687 +     2275 =    58962
# Frame  79:    56256 +     2433 =    58689
# Frame  78:    59538 +     2780 =    62318
# Frame  77:    60759 +     2539 =    63298
# Frame  76:    61460 +     2556 =    64016
# Frame  75:    63680 +     2441 =    66121
# Frame  74:    65063 +     2492 =    67555
# Frame  73:        0 +        0 =        0
# Frame  72:    69081 +      424 =    69505
# Frame  71:    68300 +      666 =    68966
# Frame  70:    67806 +      722 =    68528
# Frame  69:    67283 +      732 =    68015
# Frame  68:    69657 +      819 =    70476
# Frame  67:    67246 +      838 =    68084
# Frame  66:    67997 +      859 =    68856
# Frame  65:    63769 +      938 =    64707
# Frame  64:    60587 +      929 =    61516
# Frame  63:    59370 +     1063 =    60433
# Frame  62:        0 +        0 =        0
# Frame  61:    59368 +      378 =    59746
# Frame  60:    60289 +      803 =    61092
# Frame  59:    53590 +     1210 =    54800
# Frame  58:    65018 +     1208 =    66226
# Frame  57:    65330 +     1186 =    66516
# Frame  56:    49407 +        0 =    49407
# Frame  55:    50970 +        0 =    50970
# Frame  54:    52120 +        0 =    52120
# Frame  53:    52076 +        0 =    52076
# Frame  52:    50180 +        0 =    50180
# Frame  51:    42670 +        0 =    42670
# Frame  50:    41077 +        0 =    41077
# Frame  49:    40683 +        0 =    40683
# Frame  48:    41474 +        0 =    41474
# Frame  47:    42539 +        0 =    42539
# Frame  46:    63064 +        0 =    63064
# Frame  45:    43405 +        0 =    43405
# Frame  44:    45342 +        0 =    45342
# Frame  43:    47423 +        0 =    47423
# Frame  42:    51852 +        0 =    51852
# Frame  41:    54482 +        0 =    54482
# Frame  40:    58824 +        0 =    58824
# Frame  39:    62514 +        0 =    62514
# Frame  38:    66359 +        0 =    66359
# Frame  37:    69421 +       62 =    69483
# Frame  36:    70444 +      232 =    70676
# Frame  35:    42372 +        0 =    42372
# Frame  34:    73127 +       90 =    73217
# Frame  33:    74261 +      285 =    74546
# Frame  32:    75522 +      277 =    75799
# Frame  31:    77428 +      232 =    77660
# Frame  30:    78642 +      132 =    78774
# Frame  29:    76405 +       59 =    76464
# Frame  28:    77728 +        0 =    77728
# Frame  27:    78967 +        0 =    78967
# Frame  26:    82922 +        0 =    82922
# Frame  25:    76301 +        0 =    76301
# Frame  24:    61016 +        0 =    61016
# Frame  23:    75073 +        0 =    75073
# Frame  22:    74414 +        0 =    74414
# Frame  21:    70594 +        0 =    70594
# Frame  20:    70939 +        0 =    70939
# Frame  19:    76356 +        0 =    76356
# Frame  18:    75966 +        0 =    75966
# Frame  17:    76916 +        0 =    76916
# Frame  16:    77496 +        0 =    77496
# Frame  15:    77848 +       23 =    77871
# Frame  14:    77701 +      173 =    77874
# Frame  13:    60282 +       22 =    60304
# Frame  12:    77595 +      711 =    78306
# Frame  11:    78742 +      357 =    79099
# Frame  10:    78034 +     1090 =    79124
# Frame   9:    72744 +     1287 =    74031
# Frame   8:    69506 +     2193 =    71699
# Frame   7:    65607 +     2186 =    67793
# Frame   6:    63102 +     2074 =    65176
# Frame   5:    69156 +     1958 =    71114
# Frame   4:    68763 +     1883 =    70646
# Frame   3:    59207 +     1772 =    60979
# Frame   2:    67602 +      546 =    68148
# Frame   1:        0 +        0 =        0
# Frame   0:        0 +        0 =        0
#        0 pixels are from source Frame   0
#   569941 pixels are from source Frame   1
#   198443 pixels are from source Frame   2
#    52028 pixels are from source Frame   3
#    50370 pixels are from source Frame   4
#    33714 pixels are from source Frame   5
#    39387 pixels are from source Frame   6
#    36305 pixels are from source Frame   7
#    24835 pixels are from source Frame   8
#    24147 pixels are from source Frame   9
#     6921 pixels are from source Frame  10
#     6108 pixels are from source Frame  11
#    24291 pixels are from source Frame  12
#   373831 pixels are from source Frame  13
#    25790 pixels are from source Frame  14
#    31959 pixels are from source Frame  15
#    26582 pixels are from source Frame  16
#    22538 pixels are from source Frame  17
#    24045 pixels are from source Frame  18
#    19385 pixels are from source Frame  19
#    17125 pixels are from source Frame  20
#    19582 pixels are from source Frame  21
#     9523 pixels are from source Frame  22
#    55754 pixels are from source Frame  23
#   410982 pixels are from source Frame  24
#    60858 pixels are from source Frame  25
#    48984 pixels are from source Frame  26
#    38720 pixels are from source Frame  27
#    39894 pixels are from source Frame  28
#    38678 pixels are from source Frame  29
#    28680 pixels are from source Frame  30
#    14359 pixels are from source Frame  31
#    13691 pixels are from source Frame  32
#     8984 pixels are from source Frame  33
#    35850 pixels are from source Frame  34
#   358036 pixels are from source Frame  35
#    39857 pixels are from source Frame  36
#    38450 pixels are from source Frame  37
#    31272 pixels are from source Frame  38
#    27995 pixels are from source Frame  39
#    21077 pixels are from source Frame  40
#    17961 pixels are from source Frame  41
#    10307 pixels are from source Frame  42
#     9228 pixels are from source Frame  43
#     4224 pixels are from source Frame  44
#    62548 pixels are from source Frame  45
#   228641 pixels are from source Frame  46
#    29860 pixels are from source Frame  47
#    29855 pixels are from source Frame  48
#    28175 pixels are from source Frame  49
#    25820 pixels are from source Frame  50
#    31887 pixels are from source Frame  51
#    21856 pixels are from source Frame  52
#    14645 pixels are from source Frame  53
#    12048 pixels are from source Frame  54
#     6818 pixels are from source Frame  55
#   242786 pixels are from source Frame  56
#    23532 pixels are from source Frame  57
#     7428 pixels are from source Frame  58
#    19013 pixels are from source Frame  59
#     2499 pixels are from source Frame  60
#        0 pixels are from source Frame  61
#   421502 pixels are from source Frame  62
#    30463 pixels are from source Frame  63
#    37913 pixels are from source Frame  64
#    45664 pixels are from source Frame  65
#    28558 pixels are from source Frame  66
#    39852 pixels are from source Frame  67
#    19916 pixels are from source Frame  68
#    21520 pixels are from source Frame  69
#    15884 pixels are from source Frame  70
#     7814 pixels are from source Frame  71
#        0 pixels are from source Frame  72
#   364962 pixels are from source Frame  73
#    46348 pixels are from source Frame  74
#    38813 pixels are from source Frame  75
#    42600 pixels are from source Frame  76
#    33969 pixels are from source Frame  77
#    21588 pixels are from source Frame  78
#    27858 pixels are from source Frame  79
#    16470 pixels are from source Frame  80
#    12003 pixels are from source Frame  81
#     4985 pixels are from source Frame  82
#        0 pixels are from source Frame  83
#   257742 pixels are from source Frame  84
#    34370 pixels are from source Frame  85
#    28578 pixels are from source Frame  86
#    31740 pixels are from source Frame  87
#    23189 pixels are from source Frame  88
#    51868 pixels are from source Frame  89
#    17483 pixels are from source Frame  90
#    12351 pixels are from source Frame  91
#    10047 pixels are from source Frame  92
#     5511 pixels are from source Frame  93
#        0 pixels are from source Frame  94
#   179995 pixels are from source Frame  95
#    46001 pixels are from source Frame  96
#    36278 pixels are from source Frame  97
#    39490 pixels are from source Frame  98
#    42746 pixels are from source Frame  99
#    36952 pixels are from source Frame 100
#    32548 pixels are from source Frame 101
#    27829 pixels are from source Frame 102
#    22712 pixels are from source Frame 103
#    12433 pixels are from source Frame 104
#    55015 pixels are from source Frame 105
#    92619 pixels are from source Frame 106
#    48793 pixels are from source Frame 107
#    46396 pixels are from source Frame 108
#    38284 pixels are from source Frame 109
#    30851 pixels are from source Frame 110
#    20304 pixels are from source Frame 111
#    13742 pixels are from source Frame 112
#     8286 pixels are from source Frame 113
#     4194 pixels are from source Frame 114
#     1280 pixels are from source Frame 115
#    11570 pixels are from source Frame 116
#   389015 pixels are from source Frame 117
#    14163 pixels are from source Frame 118
#    13877 pixels are from source Frame 119
#     8659 pixels are from source Frame 120
#      512 pixels are from source Frame 121
#     4856 pixels are from source Frame 122
#     6297 pixels are from source Frame 123
#    10681 pixels are from source Frame 124
#    16708 pixels are from source Frame 125
#    31417 pixels are from source Frame 126
#   100274 pixels are from source Frame 127
#   121535 pixels are from source Frame 128
#    92410 pixels are from source Frame 129
#    86502 pixels are from source Frame 130
#    65892 pixels are from source Frame 131
#    76538 pixels are from source Frame 132
#    30823 pixels are from source Frame 133
#    35672 pixels are from source Frame 134
#    17666 pixels are from source Frame 135
#     5106 pixels are from source Frame 136
#    16464 pixels are from source Frame 137
#    34927 pixels are from source Frame 138
#   204461 pixels are from source Frame 139
#    15689 pixels are from source Frame 140
#    15022 pixels are from source Frame 141
#    14492 pixels are from source Frame 142
#     7009 pixels are from source Frame 143
#     7507 pixels are from source Frame 144
#    16256 pixels are from source Frame 145
#     7197 pixels are from source Frame 146
#     7581 pixels are from source Frame 147
#     4313 pixels are from source Frame 148
#        0 pixels are from source Frame 149
#    53171 pixels are from source Frame 149
#    71754 pixels are from source Frame 148
#    24681 pixels are from source Frame 147
#    23965 pixels are from source Frame 146
#    34963 pixels are from source Frame 145
#    14362 pixels are from source Frame 144
#    13881 pixels are from source Frame 143
#    10861 pixels are from source Frame 142
#    18507 pixels are from source Frame 141
#   104522 pixels are from source Frame 140
#    48515 pixels are from source Frame 139
#    17780 pixels are from source Frame 138
#    25310 pixels are from source Frame 137
#    22069 pixels are from source Frame 136
#    23580 pixels are from source Frame 135
#    23856 pixels are from source Frame 134
#    24540 pixels are from source Frame 133
#    46660 pixels are from source Frame 132
#    45109 pixels are from source Frame 131
#    34729 pixels are from source Frame 130
#   101958 pixels are from source Frame 129
#    39208 pixels are from source Frame 128
#    20356 pixels are from source Frame 127
#    19162 pixels are from source Frame 126
#    23403 pixels are from source Frame 125
#    18668 pixels are from source Frame 124
#    19836 pixels are from source Frame 123
#    17258 pixels are from source Frame 122
#    12505 pixels are from source Frame 121
#     9704 pixels are from source Frame 120
#     5727 pixels are from source Frame 119
#    11570 pixels are from source Frame 118
#   159332 pixels are from source Frame 117
#    29506 pixels are from source Frame 116
#    36709 pixels are from source Frame 115
#    36575 pixels are from source Frame 114
#    56724 pixels are from source Frame 113
#    47915 pixels are from source Frame 112
#    36197 pixels are from source Frame 111
#    68348 pixels are from source Frame 110
#    52930 pixels are from source Frame 109
#    33430 pixels are from source Frame 108
#   149059 pixels are from source Frame 107
#    46715 pixels are from source Frame 106
#     8692 pixels are from source Frame 105
#     5467 pixels are from source Frame 104
#     5304 pixels are from source Frame 103
#    11876 pixels are from source Frame 102
#    17808 pixels are from source Frame 101
#    12725 pixels are from source Frame 100
#    10940 pixels are from source Frame  99
#     9112 pixels are from source Frame  98
#     3328 pixels are from source Frame  97
#        0 pixels are from source Frame  96
#   213814 pixels are from source Frame  95
#    42893 pixels are from source Frame  94
#    36272 pixels are from source Frame  93
#    40209 pixels are from source Frame  92
#    38862 pixels are from source Frame  91
#    29123 pixels are from source Frame  90
#    22347 pixels are from source Frame  89
#    18453 pixels are from source Frame  88
#    12146 pixels are from source Frame  87
#     6970 pixels are from source Frame  86
#        0 pixels are from source Frame  85
#   315810 pixels are from source Frame  84
#    66786 pixels are from source Frame  83
#    32509 pixels are from source Frame  82
#    36369 pixels are from source Frame  81
#    34602 pixels are from source Frame  80
#    34558 pixels are from source Frame  79
#    25347 pixels are from source Frame  78
#    20057 pixels are from source Frame  77
#    14329 pixels are from source Frame  76
#     6943 pixels are from source Frame  75
#        0 pixels are from source Frame  74
#   466593 pixels are from source Frame  73
#    46398 pixels are from source Frame  72
#    39405 pixels are from source Frame  71
#    32112 pixels are from source Frame  70
#    29465 pixels are from source Frame  69
#    21131 pixels are from source Frame  68
#    14573 pixels are from source Frame  67
#     6573 pixels are from source Frame  66
#     3215 pixels are from source Frame  65
#     1631 pixels are from source Frame  64
#        0 pixels are from source Frame  63
#   276550 pixels are from source Frame  62
#     5736 pixels are from source Frame  61
#     5913 pixels are from source Frame  60
#    24376 pixels are from source Frame  59
#     5874 pixels are from source Frame  58
#   277367 pixels are from source Frame  57
#    40887 pixels are from source Frame  56
#    34727 pixels are from source Frame  55
#    26001 pixels are from source Frame  54
#    21386 pixels are from source Frame  53
#    15808 pixels are from source Frame  52
#    13295 pixels are from source Frame  51
#     9487 pixels are from source Frame  50
#     8506 pixels are from source Frame  49
#     5024 pixels are from source Frame  48
#    64156 pixels are from source Frame  47
#   327600 pixels are from source Frame  46
#    40696 pixels are from source Frame  45
#    36611 pixels are from source Frame  44
#    34368 pixels are from source Frame  43
#    29251 pixels are from source Frame  42
#    32827 pixels are from source Frame  41
#    39541 pixels are from source Frame  40
#    85106 pixels are from source Frame  39
#    74327 pixels are from source Frame  38
#    42286 pixels are from source Frame  37
#    53117 pixels are from source Frame  36
#   502330 pixels are from source Frame  35
#    44529 pixels are from source Frame  34
#    36157 pixels are from source Frame  33
#    28068 pixels are from source Frame  32
#    29127 pixels are from source Frame  31
#    20413 pixels are from source Frame  30
#    45233 pixels are from source Frame  29
#    39340 pixels are from source Frame  28
#    58187 pixels are from source Frame  27
#    17160 pixels are from source Frame  26
#    87915 pixels are from source Frame  25
#   417278 pixels are from source Frame  24
#    26725 pixels are from source Frame  23
#    65810 pixels are from source Frame  22
#    70520 pixels are from source Frame  21
#   103275 pixels are from source Frame  20
#    44200 pixels are from source Frame  19
#    49864 pixels are from source Frame  18
#    30751 pixels are from source Frame  17
#    35215 pixels are from source Frame  16
#    25647 pixels are from source Frame  15
#    37830 pixels are from source Frame  14
#   229883 pixels are from source Frame  13
#    17208 pixels are from source Frame  12
#    13354 pixels are from source Frame  11
#    15598 pixels are from source Frame  10
#    19730 pixels are from source Frame   9
#    15111 pixels are from source Frame   8
#    15403 pixels are from source Frame   7
#    23314 pixels are from source Frame   6
#    11619 pixels are from source Frame   5
#     3133 pixels are from source Frame   4
#    47505 pixels are from source Frame   3
#        0 pixels are from source Frame   2
#        0 pixels are from source Frame   1
#        0 pixels are from source Frame   0
# /mnt/c/Users/Björn/Documents/MiscCode/cutter/FGVC/tool/get_flowNN_gradient.py:509: RuntimeWarning: divide by zero encountered in true_divide
#   weights = (consistencyMap[HaveNN_sum, :, indFrame] * HaveNN[HaveNN_sum, :]) / ((consistencyMap[HaveNN_sum, :, indFrame] * HaveNN[HaveNN_sum, :]).sum(axis=1, keepdims=True))
# /mnt/c/Users/Björn/Documents/MiscCode/cutter/FGVC/tool/get_flowNN_gradient.py:509: RuntimeWarning: invalid value encountered in true_divide
#   weights = (consistencyMap[HaveNN_sum, :, indFrame] * HaveNN[HaveNN_sum, :]) / ((consistencyMap[HaveNN_sum, :, indFrame] * HaveNN[HaveNN_sum, :]).sum(axis=1, keepdims=True))
# Poisson blending frame   0
# Poisson blending frame   1
# Poisson blending frame   2
# Poisson blending frame   3
# Poisson blending frame   4
# Poisson blending frame   5
# Poisson blending frame   6
# Poisson blending frame   7
# Poisson blending frame   8
# Poisson blending frame   9
# Poisson blending frame  10
# Poisson blending frame  11
# Poisson blending frame  12
# Poisson blending frame  13
# Poisson blending frame  14
# Poisson blending frame  15
# Poisson blending frame  16
# Poisson blending frame  17
# Poisson blending frame  18
# Poisson blending frame  19
# Poisson blending frame  20
# Poisson blending frame  21
# Poisson blending frame  22
# Poisson blending frame  23
# Poisson blending frame  24
# Poisson blending frame  25
# Poisson blending frame  26
# Poisson blending frame  27
# Poisson blending frame  28
# Poisson blending frame  29
# Poisson blending frame  30
# Poisson blending frame  31
# Poisson blending frame  32
# Poisson blending frame  33
# Poisson blending frame  34
# Poisson blending frame  35
# Poisson blending frame  36
# Poisson blending frame  37
# Poisson blending frame  38
# Poisson blending frame  39
# Poisson blending frame  40
# Poisson blending frame  41
# Poisson blending frame  42
# Poisson blending frame  43
# Poisson blending frame  44
# Poisson blending frame  45
# Poisson blending frame  46
# Poisson blending frame  47
# Poisson blending frame  48
# Poisson blending frame  49
# Poisson blending frame  50
# Poisson blending frame  51
# Poisson blending frame  52
# Poisson blending frame  53
# Poisson blending frame  54
# Poisson blending frame  55
# Poisson blending frame  56
# Poisson blending frame  57
# Poisson blending frame  58
# Poisson blending frame  59
# Poisson blending frame  60
# Poisson blending frame  61
# Poisson blending frame  62
# Poisson blending frame  63
# Poisson blending frame  64
# Poisson blending frame  65
# Poisson blending frame  66
# Poisson blending frame  67
# Poisson blending frame  68
# Poisson blending frame  69
# Poisson blending frame  70
# Poisson blending frame  71
# Poisson blending frame  72
# Poisson blending frame  73
# Poisson blending frame  74
# Poisson blending frame  75
# Poisson blending frame  76
# Poisson blending frame  77
# Poisson blending frame  78
# Poisson blending frame  79
# Poisson blending frame  80
# Poisson blending frame  81
# Poisson blending frame  82
# Poisson blending frame  83
# Poisson blending frame  84
# Poisson blending frame  85
# Poisson blending frame  86
# Poisson blending frame  87
# Poisson blending frame  88
# Poisson blending frame  89
# Poisson blending frame  90
# Poisson blending frame  91
# Poisson blending frame  92
# Poisson blending frame  93
# Poisson blending frame  94
# Poisson blending frame  95
# Poisson blending frame  96
# Poisson blending frame  97
# Poisson blending frame  98
# Poisson blending frame  99
# Poisson blending frame 100
# Poisson blending frame 101
# Poisson blending frame 102
# Poisson blending frame 103
# Poisson blending frame 104
# Poisson blending frame 105
# Poisson blending frame 106
# Poisson blending frame 107
# Poisson blending frame 108
# Poisson blending frame 109
# Poisson blending frame 110
# Poisson blending frame 111
# Poisson blending frame 112
# Poisson blending frame 113
# Poisson blending frame 114
# Poisson blending frame 115
# Poisson blending frame 116
# Poisson blending frame 117
# Poisson blending frame 118
# Poisson blending frame 119
# Poisson blending frame 120
# Poisson blending frame 121
# Poisson blending frame 122
# Poisson blending frame 123
# Poisson blending frame 124
# Poisson blending frame 125
# Poisson blending frame 126
# Poisson blending frame 127
# Poisson blending frame 128
# Poisson blending frame 129
# Poisson blending frame 130
# Poisson blending frame 131
# Poisson blending frame 132
# Poisson blending frame 133
# Poisson blending frame 134
# Poisson blending frame 135
# Poisson blending frame 136
# Poisson blending frame 137
# Poisson blending frame 138
# Poisson blending frame 139
# Poisson blending frame 140
# Poisson blending frame 141
# Poisson blending frame 142
# Poisson blending frame 143
# Poisson blending frame 144
# Poisson blending frame 145
# Poisson blending frame 146
# Poisson blending frame 147
# Poisson blending frame 148
# Poisson blending frame 149
# Forward Pass......
# (512, 960, 2, 149)
# Frame   1:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame   2:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame   3:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame   4:        0 +      110 =      110
# (512, 960, 2, 149)
# Frame   5:        0 +      219 =      219
# (512, 960, 2, 149)
# Frame   6:        0 +      330 =      330
# (512, 960, 2, 149)
# Frame   7:        0 +      348 =      348
# (512, 960, 2, 149)
# Frame   8:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame   9:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  10:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  11:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  12:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  13:        0 +       23 =       23
# (512, 960, 2, 149)
# Frame  14:       92 +        3 =       95
# (512, 960, 2, 149)
# Frame  15:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  16:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  17:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  18:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  19:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  20:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  21:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  22:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  23:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  24:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  25:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  26:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  27:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  28:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  29:        0 +       58 =       58
# (512, 960, 2, 149)
# Frame  30:        0 +      121 =      121
# (512, 960, 2, 149)
# Frame  31:        0 +      198 =      198
# (512, 960, 2, 149)
# Frame  32:       26 +      199 =      225
# (512, 960, 2, 149)
# Frame  33:       93 +      113 =      206
# (512, 960, 2, 149)
# Frame  34:       68 +        0 =       68
# (512, 960, 2, 149)
# Frame  35:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  36:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  37:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  38:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  39:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  40:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  41:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  42:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  43:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  44:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  45:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  46:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  47:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  48:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  49:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  50:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  51:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  52:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  53:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  54:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  55:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  56:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  57:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  58:        1 +       74 =       75
# (512, 960, 2, 149)
# Frame  59:        1 +      113 =      114
# (512, 960, 2, 149)
# Frame  60:        1 +       35 =       36
# (512, 960, 2, 149)
# Frame  61:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  62:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  63:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  64:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  65:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  66:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  67:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  68:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  69:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  70:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  71:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  72:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  73:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  74:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  75:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  76:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  77:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  78:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  79:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  80:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  81:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  82:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  83:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  84:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  85:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  86:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  87:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  88:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  89:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  90:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  91:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  92:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  93:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  94:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  95:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  96:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  97:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  98:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame  99:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 100:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 101:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 102:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 103:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 104:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 105:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 106:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 107:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 108:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 109:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 110:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 111:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 112:        0 +        7 =        7
# (512, 960, 2, 149)
# Frame 113:        1 +        6 =        7
# (512, 960, 2, 149)
# Frame 114:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 115:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 116:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 117:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 118:        0 +       12 =       12
# (512, 960, 2, 149)
# Frame 119:       11 +       26 =       37
# (512, 960, 2, 149)
# Frame 120:       16 +       57 =       73
# (512, 960, 2, 149)
# Frame 121:       11 +        3 =       14
# (512, 960, 2, 149)
# Frame 122:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 123:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 124:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 125:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 126:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 127:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 128:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 129:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 130:        7 +       59 =       66
# (512, 960, 2, 149)
# Frame 131:       17 +      240 =      257
# (512, 960, 2, 149)
# Frame 132:       31 +      469 =      500
# (512, 960, 2, 149)
# Frame 133:       26 +      621 =      647
# (512, 960, 2, 149)
# Frame 134:       37 +      733 =      770
# (512, 960, 2, 149)
# Frame 135:       64 +      778 =      842
# (512, 960, 2, 149)
# Frame 136:       67 +      817 =      884
# (512, 960, 2, 149)
# Frame 137:       97 +      834 =      931
# (512, 960, 2, 149)
# Frame 138:       97 +      884 =      981
# (512, 960, 2, 149)
# Frame 139:      100 +      853 =      953
# (512, 960, 2, 149)
# Frame 140:      100 +      948 =     1048
# (512, 960, 2, 149)
# Frame 141:      573 +     1199 =     1772
# (512, 960, 2, 149)
# Frame 142:      581 +     1513 =     2094
# (512, 960, 2, 149)
# Frame 143:      612 +     1811 =     2423
# (512, 960, 2, 149)
# Frame 144:      612 +     2241 =     2853
# (512, 960, 2, 149)
# Frame 145:      730 +     2768 =     3498
# (512, 960, 2, 149)
# Frame 146:      768 +     3297 =     4065
# (512, 960, 2, 149)
# Frame 147:      795 +     3755 =     4550
# (512, 960, 2, 149)
# Frame 148:        0 +        0 =        0
# (512, 960, 2, 149)
# Frame 149:     4714 +        0 =     4714
# Backward Pass......
# Frame 148:        0 +        0 =        0
# Frame 147:     4550 +        0 =     4550
# Frame 146:     4065 +        0 =     4065
# Frame 145:     3498 +        0 =     3498
# Frame 144:     2853 +        0 =     2853
# Frame 143:     2423 +        0 =     2423
# Frame 142:     2094 +        0 =     2094
# Frame 141:     1772 +        0 =     1772
# Frame 140:     1048 +        0 =     1048
# Frame 139:      953 +        0 =      953
# Frame 138:      981 +        0 =      981
# Frame 137:      931 +        0 =      931
# Frame 136:      884 +        0 =      884
# Frame 135:      842 +        0 =      842
# Frame 134:      770 +        0 =      770
# Frame 133:      647 +        0 =      647
# Frame 132:      500 +        0 =      500
# Frame 131:      257 +        0 =      257
# Frame 130:       66 +        0 =       66
# Frame 129:        0 +        0 =        0
# Frame 128:        0 +        0 =        0
# Frame 127:        0 +        0 =        0
# Frame 126:        0 +        0 =        0
# Frame 125:        0 +        0 =        0
# Frame 124:        0 +        0 =        0
# Frame 123:        0 +        0 =        0
# Frame 122:        0 +        0 =        0
# Frame 121:       12 +        2 =       14
# Frame 120:       14 +       59 =       73
# Frame 119:        8 +       29 =       37
# Frame 118:       11 +        1 =       12
# Frame 117:        0 +        0 =        0
# Frame 116:        0 +        0 =        0
# Frame 115:        0 +        0 =        0
# Frame 114:        0 +        0 =        0
# Frame 113:        7 +        0 =        7
# Frame 112:        7 +        0 =        7
# Frame 111:        0 +        0 =        0
# Frame 110:        0 +        0 =        0
# Frame 109:        0 +        0 =        0
# Frame 108:        0 +        0 =        0
# Frame 107:        0 +        0 =        0
# Frame 106:        0 +        0 =        0
# Frame 105:        0 +        0 =        0
# Frame 104:        0 +        0 =        0
# Frame 103:        0 +        0 =        0
# Frame 102:        0 +        0 =        0
# Frame 101:        0 +        0 =        0
# Frame 100:        0 +        0 =        0
# Frame  99:        0 +        0 =        0
# Frame  98:        0 +        0 =        0
# Frame  97:        0 +        0 =        0
# Frame  96:        0 +        0 =        0
# Frame  95:        0 +        0 =        0
# Frame  94:        0 +        0 =        0
# Frame  93:        0 +        0 =        0
# Frame  92:        0 +        0 =        0
# Frame  91:        0 +        0 =        0
# Frame  90:        0 +        0 =        0
# Frame  89:        0 +        0 =        0
# Frame  88:        0 +        0 =        0
# Frame  87:        0 +        0 =        0
# Frame  86:        0 +        0 =        0
# Frame  85:        0 +        0 =        0
# Frame  84:        0 +        0 =        0
# Frame  83:        0 +        0 =        0
# Frame  82:        0 +        0 =        0
# Frame  81:        0 +        0 =        0
# Frame  80:        0 +        0 =        0
# Frame  79:        0 +        0 =        0
# Frame  78:        0 +        0 =        0
# Frame  77:        0 +        0 =        0
# Frame  76:        0 +        0 =        0
# Frame  75:        0 +        0 =        0
# Frame  74:        0 +        0 =        0
# Frame  73:        0 +        0 =        0
# Frame  72:        0 +        0 =        0
# Frame  71:        0 +        0 =        0
# Frame  70:        0 +        0 =        0
# Frame  69:        0 +        0 =        0
# Frame  68:        0 +        0 =        0
# Frame  67:        0 +        0 =        0
# Frame  66:        0 +        0 =        0
# Frame  65:        0 +        0 =        0
# Frame  64:        0 +        0 =        0
# Frame  63:        0 +        0 =        0
# Frame  62:        0 +        0 =        0
# Frame  61:        0 +        0 =        0
# Frame  60:        0 +       36 =       36
# Frame  59:        0 +      114 =      114
# Frame  58:        0 +       75 =       75
# Frame  57:        0 +        0 =        0
# Frame  56:        0 +        0 =        0
# Frame  55:        0 +        0 =        0
# Frame  54:        0 +        0 =        0
# Frame  53:        0 +        0 =        0
# Frame  52:        0 +        0 =        0
# Frame  51:        0 +        0 =        0
# Frame  50:        0 +        0 =        0
# Frame  49:        0 +        0 =        0
# Frame  48:        0 +        0 =        0
# Frame  47:        0 +        0 =        0
# Frame  46:        0 +        0 =        0
# Frame  45:        0 +        0 =        0
# Frame  44:        0 +        0 =        0
# Frame  43:        0 +        0 =        0
# Frame  42:        0 +        0 =        0
# Frame  41:        0 +        0 =        0
# Frame  40:        0 +        0 =        0
# Frame  39:        0 +        0 =        0
# Frame  38:        0 +        0 =        0
# Frame  37:        0 +        0 =        0
# Frame  36:        0 +        0 =        0
# Frame  35:        0 +        0 =        0
# Frame  34:        0 +       68 =       68
# Frame  33:        7 +      199 =      206
# Frame  32:       30 +      195 =      225
# Frame  31:       30 +      168 =      198
# Frame  30:       14 +      107 =      121
# Frame  29:       24 +       34 =       58
# Frame  28:        0 +        0 =        0
# Frame  27:        0 +        0 =        0
# Frame  26:        0 +        0 =        0
# Frame  25:        0 +        0 =        0
# Frame  24:        0 +        0 =        0
# Frame  23:        0 +        0 =        0
# Frame  22:        0 +        0 =        0
# Frame  21:        0 +        0 =        0
# Frame  20:        0 +        0 =        0
# Frame  19:        0 +        0 =        0
# Frame  18:        0 +        0 =        0
# Frame  17:        0 +        0 =        0
# Frame  16:        0 +        0 =        0
# Frame  15:        0 +        0 =        0
# Frame  14:        0 +       95 =       95
# Frame  13:       23 +        0 =       23
# Frame  12:        0 +        0 =        0
# Frame  11:        0 +        0 =        0
# Frame  10:        0 +        0 =        0
# Frame   9:        0 +        0 =        0
# Frame   8:        0 +        0 =        0
# Frame   7:      348 +        0 =      348
# ...
#        0 pixels are from source Frame  16
#        0 pixels are from source Frame  17
#        0 pixels are from source Frame  18
#        0 pixels are from source Frame  19
#        0 pixels are from source Frame  20
#        0 pixels are from source Frame  21
#        0 pixels are from source Frame  22
#        0 pixels are from source Frame  23
#        0 pixels are from source Frame  24
#        0 pixels are from source Frame  25
#        0 pixels are from source Frame  26
#        0 pixels are from source Frame  27
#        0 pixels are from source Frame  28
#        0 pixels are from source Frame  29
#        0 pixels are from source Frame  30
#        0 pixels are from source Frame  31
#        0 pixels are from source Frame  32
#        0 pixels are from source Frame  33
#        0 pixels are from source Frame  34
#        0 pixels are from source Frame  35
#        0 pixels are from source Frame  36
#        0 pixels are from source Frame  37
#        0 pixels are from source Frame  38
#        0 pixels are from source Frame  39
#        0 pixels are from source Frame  40
#        0 pixels are from source Frame  41
#        0 pixels are from source Frame  42
#        0 pixels are from source Frame  43
#        0 pixels are from source Frame  44
#        0 pixels are from source Frame  45
#        0 pixels are from source Frame  46
#        0 pixels are from source Frame  47
#        0 pixels are from source Frame  48
#        0 pixels are from source Frame  49
#        0 pixels are from source Frame  50
#        0 pixels are from source Frame  51
#        0 pixels are from source Frame  52
#        0 pixels are from source Frame  53
#        0 pixels are from source Frame  54
#        0 pixels are from source Frame  55
#        0 pixels are from source Frame  56
#        0 pixels are from source Frame  57
#        0 pixels are from source Frame  58
#        0 pixels are from source Frame  59
#        0 pixels are from source Frame  60
#        0 pixels are from source Frame  61
#        0 pixels are from source Frame  62
#        0 pixels are from source Frame  63
#        0 pixels are from source Frame  64
#        0 pixels are from source Frame  65
#        0 pixels are from source Frame  66
#        0 pixels are from source Frame  67
#        0 pixels are from source Frame  68
#        0 pixels are from source Frame  69
#        0 pixels are from source Frame  70
#        0 pixels are from source Frame  71
#        0 pixels are from source Frame  72
#        0 pixels are from source Frame  73
#        0 pixels are from source Frame  74
#        0 pixels are from source Frame  75
#        0 pixels are from source Frame  76
#        0 pixels are from source Frame  77
#        0 pixels are from source Frame  78
#        0 pixels are from source Frame  79
#        0 pixels are from source Frame  80
#        0 pixels are from source Frame  81
#        0 pixels are from source Frame  82
#        0 pixels are from source Frame  83
#        0 pixels are from source Frame  84
#        0 pixels are from source Frame  85
#        0 pixels are from source Frame  86
#        0 pixels are from source Frame  87
#        0 pixels are from source Frame  88
#        0 pixels are from source Frame  89
#        0 pixels are from source Frame  90
#        0 pixels are from source Frame  91
#        0 pixels are from source Frame  92
#        0 pixels are from source Frame  93
#        0 pixels are from source Frame  94
#        0 pixels are from source Frame  95
#        0 pixels are from source Frame  96
#        0 pixels are from source Frame  97
#        0 pixels are from source Frame  98
#        0 pixels are from source Frame  99
#        0 pixels are from source Frame 100
#        0 pixels are from source Frame 101
#        0 pixels are from source Frame 102
#        0 pixels are from source Frame 103
#        0 pixels are from source Frame 104
#        0 pixels are from source Frame 105
#        0 pixels are from source Frame 106
#        0 pixels are from source Frame 107
#        0 pixels are from source Frame 108
#        0 pixels are from source Frame 109
#        0 pixels are from source Frame 110
#        0 pixels are from source Frame 111
#        0 pixels are from source Frame 112
#        0 pixels are from source Frame 113
#        0 pixels are from source Frame 114
#        0 pixels are from source Frame 115
#        0 pixels are from source Frame 116
#        0 pixels are from source Frame 117
#        0 pixels are from source Frame 118
#        0 pixels are from source Frame 119
#        0 pixels are from source Frame 120
#        0 pixels are from source Frame 121
#        0 pixels are from source Frame 122
#        0 pixels are from source Frame 123
#        0 pixels are from source Frame 124
#        0 pixels are from source Frame 125
#        0 pixels are from source Frame 126
#        0 pixels are from source Frame 127
#        0 pixels are from source Frame 128
#        0 pixels are from source Frame 129
#        0 pixels are from source Frame 130
#        0 pixels are from source Frame 131
#        0 pixels are from source Frame 132
#        0 pixels are from source Frame 133
#        0 pixels are from source Frame 134
#        0 pixels are from source Frame 135
#        0 pixels are from source Frame 136
#        0 pixels are from source Frame 137
#        0 pixels are from source Frame 138
#        0 pixels are from source Frame 139
#        0 pixels are from source Frame 140
#        0 pixels are from source Frame 141
#        0 pixels are from source Frame 142
#        0 pixels are from source Frame 143
#        0 pixels are from source Frame 144
#        0 pixels are from source Frame 145
#        0 pixels are from source Frame 146
#        0 pixels are from source Frame 147
#        0 pixels are from source Frame 148
#        0 pixels are from source Frame 149
#        0 pixels are from source Frame 149
#        0 pixels are from source Frame 148
#        0 pixels are from source Frame 147
#        0 pixels are from source Frame 146
#        0 pixels are from source Frame 145
#        0 pixels are from source Frame 144
#        0 pixels are from source Frame 143
#        0 pixels are from source Frame 142
#        0 pixels are from source Frame 141
#        0 pixels are from source Frame 140
#        0 pixels are from source Frame 139
#        0 pixels are from source Frame 138
#        0 pixels are from source Frame 137
#        0 pixels are from source Frame 136
#        0 pixels are from source Frame 135
#        0 pixels are from source Frame 134
#        0 pixels are from source Frame 133
#        0 pixels are from source Frame 132
#        0 pixels are from source Frame 131
#        0 pixels are from source Frame 130
#        0 pixels are from source Frame 129
#        0 pixels are from source Frame 128
#        0 pixels are from source Frame 127
#        0 pixels are from source Frame 126
#        0 pixels are from source Frame 125
#        0 pixels are from source Frame 124
#        0 pixels are from source Frame 123
#        0 pixels are from source Frame 122
#        0 pixels are from source Frame 121
#       10 pixels are from source Frame 120
#        0 pixels are from source Frame 119
#        0 pixels are from source Frame 118
#        0 pixels are from source Frame 117
#        0 pixels are from source Frame 116
#        0 pixels are from source Frame 115
#        0 pixels are from source Frame 114
#        0 pixels are from source Frame 113
#        0 pixels are from source Frame 112
#        0 pixels are from source Frame 111
#        0 pixels are from source Frame 110
#        0 pixels are from source Frame 109
#        0 pixels are from source Frame 108
#        0 pixels are from source Frame 107
#        0 pixels are from source Frame 106
#        0 pixels are from source Frame 105
#        0 pixels are from source Frame 104
#        0 pixels are from source Frame 103
#        0 pixels are from source Frame 102
#        0 pixels are from source Frame 101
#        0 pixels are from source Frame 100
#        0 pixels are from source Frame  99
#        0 pixels are from source Frame  98
#        0 pixels are from source Frame  97
#        0 pixels are from source Frame  96
#        0 pixels are from source Frame  95
#        0 pixels are from source Frame  94
#        0 pixels are from source Frame  93
#        0 pixels are from source Frame  92
#        0 pixels are from source Frame  91
#        0 pixels are from source Frame  90
#        0 pixels are from source Frame  89
#        0 pixels are from source Frame  88
#        0 pixels are from source Frame  87
#        0 pixels are from source Frame  86
#        0 pixels are from source Frame  85
#        0 pixels are from source Frame  84
#        0 pixels are from source Frame  83
#        0 pixels are from source Frame  82
#        0 pixels are from source Frame  81
#        0 pixels are from source Frame  80
#        0 pixels are from source Frame  79
#        0 pixels are from source Frame  78
#        0 pixels are from source Frame  77
#        0 pixels are from source Frame  76
#        0 pixels are from source Frame  75
#        0 pixels are from source Frame  74
#        0 pixels are from source Frame  73
#        0 pixels are from source Frame  72
#        0 pixels are from source Frame  71
#        0 pixels are from source Frame  70
#        0 pixels are from source Frame  69
#        0 pixels are from source Frame  68
#        0 pixels are from source Frame  67
#        0 pixels are from source Frame  66
#        0 pixels are from source Frame  65
#        0 pixels are from source Frame  64
#        0 pixels are from source Frame  63
#        0 pixels are from source Frame  62
#        0 pixels are from source Frame  61
#        0 pixels are from source Frame  60
#        0 pixels are from source Frame  59
#        0 pixels are from source Frame  58
#        0 pixels are from source Frame  57
#        0 pixels are from source Frame  56
#        0 pixels are from source Frame  55
#        0 pixels are from source Frame  54
#        0 pixels are from source Frame  53
#        0 pixels are from source Frame  52
#        0 pixels are from source Frame  51
#        0 pixels are from source Frame  50
#        0 pixels are from source Frame  49
#        0 pixels are from source Frame  48
#        0 pixels are from source Frame  47
#        0 pixels are from source Frame  46
#        0 pixels are from source Frame  45
#        0 pixels are from source Frame  44
#        0 pixels are from source Frame  43
#        0 pixels are from source Frame  42
#        0 pixels are from source Frame  41
#        0 pixels are from source Frame  40
#        0 pixels are from source Frame  39
#        0 pixels are from source Frame  38
#        0 pixels are from source Frame  37
#        0 pixels are from source Frame  36
#        0 pixels are from source Frame  35
#        0 pixels are from source Frame  34
#        0 pixels are from source Frame  33
#        0 pixels are from source Frame  32
#        0 pixels are from source Frame  31
#        0 pixels are from source Frame  30
#        0 pixels are from source Frame  29
#        0 pixels are from source Frame  28
#        0 pixels are from source Frame  27
#        0 pixels are from source Frame  26
#        0 pixels are from source Frame  25
#        0 pixels are from source Frame  24
#        0 pixels are from source Frame  23
#        0 pixels are from source Frame  22
#        0 pixels are from source Frame  21
#        0 pixels are from source Frame  20
#        0 pixels are from source Frame  19
#        0 pixels are from source Frame  18
#        0 pixels are from source Frame  17
#        0 pixels are from source Frame  16
#        0 pixels are from source Frame  15
#        0 pixels are from source Frame  14
#        0 pixels are from source Frame  13
#        0 pixels are from source Frame  12
#        0 pixels are from source Frame  11
#        0 pixels are from source Frame  10
#        0 pixels are from source Frame   9
#        0 pixels are from source Frame   8
#        0 pixels are from source Frame   7
#        0 pixels are from source Frame   6
#        0 pixels are from source Frame   5
#        0 pixels are from source Frame   4
#        0 pixels are from source Frame   3
#        0 pixels are from source Frame   2
#        0 pixels are from source Frame   1
#        0 pixels are from source Frame   0
# Poisson blending frame   0
# Poisson blending frame   1
# Poisson blending frame   2
# Poisson blending frame   3
# Poisson blending frame   4
# Poisson blending frame   5
# Poisson blending frame   6
# Poisson blending frame   7
# Poisson blending frame   8
# Poisson blending frame   9
# Poisson blending frame  10
# Poisson blending frame  11
# Poisson blending frame  12
# Poisson blending frame  13
# Poisson blending frame  14
# Poisson blending frame  15
# Poisson blending frame  16
# Poisson blending frame  17
# Poisson blending frame  18
# Poisson blending frame  19
# Poisson blending frame  20
# Poisson blending frame  21
# Poisson blending frame  22
# Poisson blending frame  23
# Poisson blending frame  24
# Poisson blending frame  25
# Poisson blending frame  26
# Poisson blending frame  27
# Poisson blending frame  28
# Poisson blending frame  29
# Poisson blending frame  30
# Poisson blending frame  31
# Poisson blending frame  32
# Poisson blending frame  33
# Poisson blending frame  34
# Poisson blending frame  35
# Poisson blending frame  36
# Poisson blending frame  37
# Poisson blending frame  38
# Poisson blending frame  39
# Poisson blending frame  40
# Poisson blending frame  41
# Poisson blending frame  42
# Poisson blending frame  43
# Poisson blending frame  44
# Poisson blending frame  45
# Poisson blending frame  46
# Poisson blending frame  47
# Poisson blending frame  48
# Poisson blending frame  49
# Poisson blending frame  50
# Poisson blending frame  51
# Poisson blending frame  52
# Poisson blending frame  53
# Poisson blending frame  54
# Poisson blending frame  55
# Poisson blending frame  56
# Poisson blending frame  57
# Poisson blending frame  58
# Poisson blending frame  59
# Poisson blending frame  60
# Poisson blending frame  61
# Poisson blending frame  62
# Poisson blending frame  63
# Poisson blending frame  64
# Poisson blending frame  65
# Poisson blending frame  66
# Poisson blending frame  67
# Poisson blending frame  68
# Poisson blending frame  69
# Poisson blending frame  70
# Poisson blending frame  71
# Poisson blending frame  72
# Poisson blending frame  73
# Poisson blending frame  74
# Poisson blending frame  75
# Poisson blending frame  76
# Poisson blending frame  77
# Poisson blending frame  78
# Poisson blending frame  79
# Poisson blending frame  80
# Poisson blending frame  81
# Poisson blending frame  82
# Poisson blending frame  83
# Poisson blending frame  84
# Poisson blending frame  85
# Poisson blending frame  86
# Poisson blending frame  87
# Poisson blending frame  88
# Poisson blending frame  89
# Poisson blending frame  90
# Poisson blending frame  91
# Poisson blending frame  92
# Poisson blending frame  93
# Poisson blending frame  94
# Poisson blending frame  95
# Poisson blending frame  96
# Poisson blending frame  97
# Poisson blending frame  98
# Poisson blending frame  99
# Poisson blending frame 100
# Poisson blending frame 101
# Poisson blending frame 102
# Poisson blending frame 103
# Poisson blending frame 104
# Poisson blending frame 105
# Poisson blending frame 106
# Poisson blending frame 107
# Poisson blending frame 108
# Poisson blending frame 109
# Poisson blending frame 110
# Poisson blending frame 111
# Poisson blending frame 112
# Poisson blending frame 113
# Poisson blending frame 114
# Poisson blending frame 115
# Poisson blending frame 116
# Poisson blending frame 117
# Poisson blending frame 118
# Poisson blending frame 119
# Poisson blending frame 120
# Poisson blending frame 121
# Poisson blending frame 122
# Poisson blending frame 123
# Poisson blending frame 124
# Poisson blending frame 125
# Poisson blending frame 126
# Poisson blending frame 127
# Poisson blending frame 128
# Poisson blending frame 129
# Poisson blending frame 130
# Poisson blending frame 131
# Poisson blending frame 132
# Poisson blending frame 133
# Poisson blending frame 134
# Poisson blending frame 135
# Poisson blending frame 136
# Poisson blending frame 137
# Poisson blending frame 138
# Poisson blending frame 139
# Poisson blending frame 140
# Poisson blending frame 141
# Poisson blending frame 142
# Poisson blending frame 143
# Poisson blending frame 144
# Poisson blending frame 145
# Poisson blending frame 146
# Poisson blending frame 147
# Poisson blending frame 148
# Poisson blending frame 149
# done

# %%
from ipywidgets import Video
Video.fromfile(f"{output_dir}/frame_seamless_comp_0/video_extrapolation.mp4")
